# %% [markdown]
# # Tidying the Data
# The data that we have here today is a little special: it comes as a json file with nested lists. We will need to untangle and flatten this data set before we can make use of the machine learning tools we will be using in R.

# %% [markdown]
# ## Importing the Data Set
# To start off, we need to take a look at the data set and explore what it has to offer. Upon first look, we can see that the data comes in a nested format, with each outfit having the attributes `name`, `views`, `items`, `image`, `likes`, `date`, `set_url`, and `desc`. The `items` attribute is nested, which means it has its own set of attributes within it. This includes `index`, `name`, `price`, `likes`, `image`, and `categoryid`, which all describe parts of an outfit.
#
# The data also comes pre-split, but for the sake of this project, we will need to recombine them.

# %%
import pandas as pd
import json
from collections import Counter

f = open('polyvore_data/train_no_dup.json')
dict1 = json.load(f)
f.close()
f = open('polyvore_data/valid_no_dup.json')
dict2 = json.load(f)
f.close()
f = open('polyvore_data/test_no_dup.json')
dict3 = json.load(f)
f.close()

df1 = pd.json_normalize(dict1)
df2 = pd.json_normalize(dict2)
df3 = pd.json_normalize(dict3)

dflist = [df1, df2, df3]
df = pd.concat(dflist)

# %%
df.head(3)
# Out:
#                                                 name  views  \
# 0                                             Casual   8743
# 1  Being a Vans shoe model with Luke. Idk about t...    188
# 2                These Chanel bags is a bad habit .x    562
#
#                                                items  \
# 0  [{'index': 1, 'name': 'mock neck embroidery su...
# 1  [{'index': 1, 'name': 'nirvana distressed t-sh...
# 2  [{'index': 1, 'name': 'monki singlet', 'price'...
#
#                                                image  likes       date  \
# 0  http://ak1.polyvoreimg.com/cgi/img-set/cid/214...    394  One month
# 1  http://ak1.polyvoreimg.com/cgi/img-set/cid/120...      9  Two years
# 2  http://ak1.polyvoreimg.com/cgi/img-set/cid/143...     32  Two years
#
#                                              set_url     set_id  \
# 0    http://www.polyvore.com/casual/set?id=214181831  214181831
# 1  http://www.polyvore.com/being_vans_shoe_model_...  120161271
# 2  http://www.polyvore.com/these_chanel_bags_is_b...  143656996
#
#                                                 desc
# 0  A fashion look from January 2017 by beebeely-l...
# 1  A fashion look from April 2014 featuring destr...
# 2                                           12.19.14

# %%
df.shape
# Out:
# (21889, 9)

# %%
df['items'].loc[1,][0:2]
# Out:
# C:\Users\bella\AppData\Local\Temp\ipykernel_868\386284.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   df['items'].loc[1,][0:2]
# 1    [{'index': 1, 'name': 'nirvana distressed t-sh...
# 1    [{'index': 1, 'name': 'classic bracelet', 'pri...
# Name: items, dtype: object

# %% [markdown]
# ## Unnesting the Data
# The attributes that I'm interested within each item are `name` and `categoryid` since they give the most information about the visual aspects of the outfit which is what I want to focus on. I've created a function that extracts this information and pivots them into their own columns.

# %%
def itemscol_to_dataframe(column):
    data = []

    for index, sublist in column.items():
        name_list = []
        category_list = []

        for item in sublist:
            name_list.append(item['name'])
            category_list.append(item['categoryid'])

        if len(name_list) < 8:
            fill = 8 - len(name_list)
            name_list = name_list + (['empty'] * fill)
            category_list = category_list + ([0] * fill)
        row = name_list + category_list
        data.append(row)
        
    itemsdf = pd.DataFrame(data, columns = ['iname1', 'iname2', 'iname3', 'iname4',
                                        'iname5', 'iname6', 'iname7', 'iname8',
                                        'iid1', 'iid2', 'iid3', 'iid4',
                                        'iid5', 'iid6', 'iid7', 'iid8'])
    return itemsdf

# %%
items_df = itemscol_to_dataframe(df['items'])
items_df.head(2)
# Out:
#                                   iname1                               iname2  \
# 0  mock neck embroidery suede sweatshirt        luxe double zip hooded jacket
# 1             nirvana distressed t-shirt  rag bone rock w/ black skinny jeans
#
#                                         iname3  \
# 0  citizens humanity high rise rocket hem jean
# 1           vans authentic black mono trainers
#
#                                iname4                        iname5  \
# 0               suede tie short boots  cloth travel school backpack
# 1  time low rubber bracelet hot topic     veil logo rubber bracelet
#
#                       iname6       iname7  \
# 0                                polyvore
# 1  rubber bracelet hot topic  romance i'm
#
#                                               iname8  iid1  iid2  iid3  iid4  \
# 0                                              empty  4495    25    27   261
# 1  disney alice wonderland cat rubber bracelet ho...    21   237    49   106
#
#    iid5  iid6  iid7  iid8
# 0   259  1967     2     0
# 1   106   106   106   106

# %% [markdown]
# Since there can be up to 8 items in an outfit, this dataframe contains 8 * 2 = 16 columns. Outfits with fewer items have their excess item name and item id columns filled with `'empty'` and `0`, respectively. I've chosen not to use `NULL` / `N/A` here since this isn't really "missing" information; rather, it gives us information on how many items are in the outfit which might be useful.
#
# Now we can combine this with the full dataframe, dropping unnecessary columns, and export it as a csv!

# %%
df2 = df1.drop(columns = ['items', 'image', 'name', 
                        'date', 'set_url', 'desc']
        ).join(items_df)
df2.head(3)
# Out:
#    views  likes     set_id                                 iname1  \
# 0   8743    394  214181831  mock neck embroidery suede sweatshirt
# 1    188      9  120161271             nirvana distressed t-shirt
# 2    562     32  143656996                          monki singlet
#
#                                 iname2  \
# 0        luxe double zip hooded jacket
# 1  rag bone rock w/ black skinny jeans
# 2                     joy denim jacket
#
#                                         iname3  \
# 0  citizens humanity high rise rocket hem jean
# 1           vans authentic black mono trainers
# 2     topshop moto joni high rise skinny jeans
#
#                                iname4                         iname5  \
# 0               suede tie short boots   cloth travel school backpack
# 1  time low rubber bracelet hot topic      veil logo rubber bracelet
# 2         black pointed chelsea boots  pre-owned chanel shoulder bag
#
#                         iname6       iname7  \
# 0                                  polyvore
# 1    rubber bracelet hot topic  romance i'm
# 2  rag bone floppy brim fedora        empty
#
#                                               iname8  iid1  iid2  iid3  iid4  \
# 0                                              empty  4495    25    27   261
# 1  disney alice wonderland cat rubber bracelet ho...    21   237    49   106
# 2                                              empty   104    25   237   261
#
#    iid5  iid6  iid7  iid8
# 0   259  1967     2     0
# 1   106   106   106   106
# 2    37    55     0     0

# %%
df2['inametotal'] = df2['iname1'] + ' ' + df2['iname2'] + ' ' + df2['iname3'] + ' ' + df2['iname4'] + ' ' + df2['iname5'] + ' ' + df2['iname6'] + ' ' + df2['iname7'] + ' ' + df2['iname8']
all_item_names = df2['inametotal'].str.cat(sep = ' ')
all_item_names

item_word_list = all_item_names.split()
counter = Counter(item_word_list)
most_occur = counter.most_common(100)
most_occur
# Out:
# [('empty', 23722),
#  ('black', 9909),
#  ('leather', 8516),
#  ('bag', 6350),
#  ("women's", 5810),
#  ('top', 4504),
#  ('jeans', 4133),
#  ('dress', 4100),
#  ('gold', 4031),
#  ('white', 3837),
#  ('earrings', 3619),
#  ('iphone', 3613),
#  ('sunglasses', 3382),
#  ('necklace', 3381),
#  ('skirt', 3254),
#  ('boots', 3142),
#  ('suede', 3004),
#  ('jacket', 2922),
#  ('case', 2871),
#  ('denim', 2763),
#  ('ring', 2703),
#  ('mini', 2622),
#  ('yoins', 2563),
#  ('high', 2535),
#  ('blue', 2533),
#  ('clutch', 2497),
#  ('plus', 2465),
#  ('bracelet', 2418),
#  ('skinny', 2164),
#  ('coat', 2127),
#  ('shoulder', 2125),
#  ('sandals', 2122),
#  ('long', 2112),
#  ('set', 2106),
#  ('women', 2106),
#  ('lace', 2069),
#  ('red', 2014),
#  ('new', 1996),
#  ('print', 1986),
#  ('pink', 1961),
#  ('sleeve', 1954),
#  ('ankle', 1949),
#  ('silver', 1894),
#  ('pre-owned', 1877),
#  ('lipstick', 1861),
#  ('shorts', 1850),
#  ('topshop', 1818),
#  ('sweater', 1788),
#  ('size', 1749),
#  ('faux', 1711),
#  ('vintage', 1699),
#  ('shoes', 1693),
#  ('rose', 1689),
#  ('pumps', 1651),
#  ('de', 1642),
#  ('crop', 1634),
#  ('michael', 1634),
#  ('color', 1598),
#  ('eye', 1554),
#  ('watch', 1541),
#  ('shirt', 1538),
#  ('round', 1527),
#  ('backpack', 1526),
#  ('diamond', 1506),
#  ('brown', 1499),
#  ('tote', 1477),
#  ('velvet', 1474),
#  ('floral', 1454),
#  ('neck', 1382),
#  ('lip', 1372),
#  ('saint', 1356),
#  ('laurent', 1328),
#  ('cropped', 1299),
#  ('stud', 1282),
#  ('wool', 1278),
#  ('blouse', 1277),
#  ('sheinside', 1264),
#  ('shein', 1260),
#  ('t-shirt', 1209),
#  ('chanel', 1199),
#  ('small', 1191),
#  ('gucci', 1187),
#  ('crossbody', 1185),
#  ('fashion', 1184),
#  ('kate', 1170),
#  ('short', 1156),
#  ('strap', 1156),
#  ('star', 1154),
#  ('classic', 1154),
#  ('sneakers', 1153),
#  ('womens', 1151),
#  ('heel', 1137),
#  ('cover', 1101),
#  ('kors', 1075),
#  ('toe', 1075),
#  ('hat', 1066),
#  ('nail', 1061),
#  ('grey', 1051),
#  ('chain', 1044),
#  ('platform', 1043)]

# %%
import os

all_files = os.listdir('color_synonyms/')
all_files

def get_color_synonyms(folder):
    all_files = os.listdir(folder)
    colordict = {}
    for file in all_files:
        f = open(folder + file)
        data = f.read()
        f.close()
        colordict[file[:-4]] = data.split('\n')
    return colordict

colordict = get_color_synonyms('color_synonyms/')
colordict

def what_color(itemname):
    itemnamelist = itemname.split()
    color = []
    for item in itemnamelist:
        for key in colordict:
            if item in colordict[key]:
                color.append(key)
    return list(set(color))[0:4]#' '.join(set(color))

# %%
df2['colors'] = df2['inametotal'].apply(what_color)
df2.head(10)
#len(df2['colors'].unique()) # there are 749 color combinations.
# Out:
#    views  likes     set_id                                             iname1  \
# 0   8743    394  214181831              mock neck embroidery suede sweatshirt
# 1    188      9  120161271                         nirvana distressed t-shirt
# 2    562     32  143656996                                      monki singlet
# 3   2613     88  186627934                                               tops
# 4     62      3  206969379      yoins leather sexy v-neck sleeveless crop top
# 5    276     83  201969694  new look light blue denim oversized long sleev...
# 6   1580    395  216470135                  isabel marant alpaca blend jumper
# 7    591    233  216220312                        oasis shadow bird knit pink
# 8   1142    239  185225843               valentino pleated cotton-blend dress
# 9  24915    492  213824660                  yoins plus size blue stripe shirt
#
#                                               iname2  \
# 0                      luxe double zip hooded jacket
# 1                rag bone rock w/ black skinny jeans
# 2                                   joy denim jacket
# 3  saint laurent zip cutout stretch nappa leather...
# 4           solid color long sleeve irregular blazer
# 5                          mango skinny jane jegging
# 6   yoins light blue gradient color hole denim skirt
# 7  michelle mason women's suede wrap front mini s...
# 8                 valentino red ruffle detail blouse
# 9                yoins grey sleeveless faux fur coat
#
#                                               iname3  \
# 0        citizens humanity high rise rocket hem jean
# 1                 vans authentic black mono trainers
# 2           topshop moto joni high rise skinny jeans
# 3  corset super store women's black steampunk corset
# 4           alice+olivia floral pattern a-line skirt
# 5             sophia webster leather butterfly flats
# 6       alice light blue shoes flats leather sandals
# 7                    chloé lauren leather ballerinas
# 8                          valentino wool-blend coat
# 9               topshop moto dark indigo jamie jeans
#
#                                               iname4  \
# 0                              suede tie short boots
# 1                 time low rubber bracelet hot topic
# 2                        black pointed chelsea boots
# 3  allurez square diamond halo engagement ring we...
# 4                          zipped top chunky booties
# 5      michael michael kors mini selma crossbody bag
# 6  yoins beige leather-look gold-tone metal clutc...
# 7         giuseppe zanotti patent-leather clutch bag
# 8          valentino rockstud metallic leather pumps
# 9  yoins grey buckle design chunky heels short boots
#
#                                      iname5  \
# 0              cloth travel school backpack
# 1                 veil logo rubber bracelet
# 2             pre-owned chanel shoulder bag
# 3    lip buckled matte womens corset lip uk
# 4  gold boho turquoise leaf tassel earrings
# 5          velvet vase embellished necklace
# 6         yoins stone long pendant necklace
# 7                hermÃ¨s rose gold bracelet
# 8   valentino small striped leather satchel
# 9                       wild side mini hair
#
#                                   iname6  \
# 0
# 1              rubber bracelet hot topic
# 2            rag bone floppy brim fedora
# 3                     nude pink lipstick
# 4             etro heart locket necklace
# 5          powder eye shadow deep sea ea
# 6                     elizabeth mini set
# 7     deborah lippmann creme nail polish
# 8  valentino printed cashmere silk scarf
# 9                      bobbi brown peach
#
#                                               iname7  ...  iid1  iid2  iid3  \
# 0                                           polyvore  ...  4495    25    27
# 1                                        romance i'm  ...    21   237    49
# 2                                              empty  ...   104    25   237
# 3                            amazing eye makeup miss  ...    11    28     2
# 4  bohemian flower mandala blue crystal clear pho...  ...    11   236     9
# 5                                              empty  ...    11   241    47
# 6                                                     ...    19     9    41
# 7                                              empty  ...    19     8    47
# 8                                              empty  ...     4    17    24
# 9                                                set  ...    11    24   237
#
#    iid4  iid5  iid6  iid7  iid8  \
# 0   261   259  1967     2     0
# 1   106   106   106   106   106
# 2   261    37    55     0     0
# 3    65    52   200   186    76
# 4   261    64    62  1967   200
# 5    37    62   196     0     0
# 6    38    62   140  4438     0
# 7    38   106   222     0     0
# 8    43   318   105     0     0
# 9   261    58   188   171    37
#
#                                           inametotal  \
# 0  mock neck embroidery suede sweatshirt luxe dou...
# 1  nirvana distressed t-shirt rag bone rock w/ bl...
# 2  monki singlet joy denim jacket topshop moto jo...
# 3  tops saint laurent zip cutout stretch nappa le...
# 4  yoins leather sexy v-neck sleeveless crop top ...
# 5  new look light blue denim oversized long sleev...
# 6  isabel marant alpaca blend jumper yoins light ...
# 7  oasis shadow bird knit pink michelle mason wom...
# 8  valentino pleated cotton-blend dress valentino...
# 9  yoins plus size blue stripe shirt yoins grey s...
#
#                        colors
# 0                          []
# 1              [white, black]
# 2        [white, black, blue]
# 3        [black, red, yellow]
# 4  [black, red, blue, yellow]
# 5        [white, black, blue]
# 6  [gray, black, blue, brown]
# 7        [black, red, yellow]
# 8          [black, red, gray]
# 9    [brown, red, blue, gray]
#
# [10 rows x 21 columns]

# %%
(df2['colors'].values == '').sum() / len(df2)
# couldn't get color info on 5% of the data. will drop this since there is a lot of data to work with.
# Out:
# 0.0

# %%
len(df2.iloc[df2['colors'].apply(len).idxmax(),:].colors) # the max length of the color list is 8(damn)
# Out:
# 4

# %% [markdown]
# ## Extracting Color Information
# To deal with this data set, I will need to extract the color information from the item names. To do this, I've created a folder, `color_synonyms`, that contains 10 text files of 10 main colors. Each file contains synonyms for that color (I've also opted to put brown into the orange category since brown is essentially dark orange). Initially, I was tempted to only do red, yellow, orange, green, blue, purple, and gray (which would include black, gray, white), but seeing that one of the most common colors was black, I felt it was important to differentiate between black, gray, and white.
#
# Using these text files, I've created a function that turns each file in the folder into a dictionary where each color name corresponds to a list of its synonyms. Using this dictionary, I made another function that takes a string and returns a list of all of the unique colors contained in that string. For example:
#
# `item = 'cream dress with gold accent white lace detail'`
#
# `what_color(item)`
#
# `output: ['white', 'yellow']`
#
# I applied this function to the `inametotal` column, which contains all of the item names together as one string. Given that the main outfit items are always listed in the first few objects, I will limit the colors to 4. Once we have this info, we can drop the iname columns and replace them with 4 new columns: `color_1`, `color_2`, `color_3`, and `color_4`. I will also drop entries where there is no color for `color_1`, since we won't have any color info on that outfit. I'll replace the remaining empty strings with 'none', since I don't want them treated as missing values (since it gives information on how many colors are in the outfit).

# %%
def what_color(itemname):
    itemnamelist = itemname.split()
    color = []

    for item in itemnamelist:
        for key in colordict:
            if item in colordict[key]:
                color.append(key)

    colorlist = list(set(color))[0:4]
    fill = 4 - len(colorlist)
    colorlist = colorlist + ([''] * fill)
    
    return colorlist

# %%
df2['colors'] = df2['inametotal'].apply(what_color)
df2.head()
# Out:
#    views  likes     set_id                                         iname1  \
# 0   8743    394  214181831          mock neck embroidery suede sweatshirt
# 1    188      9  120161271                     nirvana distressed t-shirt
# 2    562     32  143656996                                  monki singlet
# 3   2613     88  186627934                                           tops
# 4     62      3  206969379  yoins leather sexy v-neck sleeveless crop top
#
#                                               iname2  \
# 0                      luxe double zip hooded jacket
# 1                rag bone rock w/ black skinny jeans
# 2                                   joy denim jacket
# 3  saint laurent zip cutout stretch nappa leather...
# 4           solid color long sleeve irregular blazer
#
#                                               iname3  \
# 0        citizens humanity high rise rocket hem jean
# 1                 vans authentic black mono trainers
# 2           topshop moto joni high rise skinny jeans
# 3  corset super store women's black steampunk corset
# 4           alice+olivia floral pattern a-line skirt
#
#                                               iname4  \
# 0                              suede tie short boots
# 1                 time low rubber bracelet hot topic
# 2                        black pointed chelsea boots
# 3  allurez square diamond halo engagement ring we...
# 4                          zipped top chunky booties
#
#                                      iname5                       iname6  \
# 0              cloth travel school backpack
# 1                 veil logo rubber bracelet    rubber bracelet hot topic
# 2             pre-owned chanel shoulder bag  rag bone floppy brim fedora
# 3    lip buckled matte womens corset lip uk           nude pink lipstick
# 4  gold boho turquoise leaf tassel earrings   etro heart locket necklace
#
#                                               iname7  ...  iid1  iid2  iid3  \
# 0                                           polyvore  ...  4495    25    27
# 1                                        romance i'm  ...    21   237    49
# 2                                              empty  ...   104    25   237
# 3                            amazing eye makeup miss  ...    11    28     2
# 4  bohemian flower mandala blue crystal clear pho...  ...    11   236     9
#
#    iid4  iid5  iid6  iid7  iid8  \
# 0   261   259  1967     2     0
# 1   106   106   106   106   106
# 2   261    37    55     0     0
# 3    65    52   200   186    76
# 4   261    64    62  1967   200
#
#                                           inametotal  \
# 0  mock neck embroidery suede sweatshirt luxe dou...
# 1  nirvana distressed t-shirt rag bone rock w/ bl...
# 2  monki singlet joy denim jacket topshop moto jo...
# 3  tops saint laurent zip cutout stretch nappa le...
# 4  yoins leather sexy v-neck sleeveless crop top ...
#
#                        colors
# 0                    [, , , ]
# 1          [white, black, , ]
# 2      [white, black, blue, ]
# 3      [black, red, yellow, ]
# 4  [black, red, blue, yellow]
#
# [5 rows x 21 columns]

# %%
df2[['color_1', 'color_2', 'color_3', 'color_4']] = pd.DataFrame(df2.colors.to_list(), index = df2.index)
df2.head()
df3 = df2.drop(columns=['iname1', 'iname2', 'iname3', 'iname4', 'iname5', 'iname6', 'iname7', 'iname8', 'colors', 'inametotal'])[df2['color_1'] != ''].reset_index(drop=True)
df3[['color_2', 'color_3', 'color_4']] = df3[['color_2', 'color_3', 'color_4']].replace('', 'none', regex=True)
df3
# Out:
#        views  likes     set_id  iid1  iid2  iid3  iid4  iid5  iid6  iid7  \
# 0        188      9  120161271    21   237    49   106   106   106   106
# 1        562     32  143656996   104    25   237   261    37    55     0
# 2       2613     88  186627934    11    28     2    65    52   200   186
# 3         62      3  206969379    11   236     9   261    64    62  1967
# 4        276     83  201969694    11   241    47    37    62   196     0
# ...      ...    ...        ...   ...   ...   ...   ...   ...   ...   ...
# 16427    183    117  216801059   104     9    47    35  4428   319     0
# 16428   2428    382  190488700    17   236    28   261    36     0     0
# 16429   2184    398  187504514     4    24    46    37    65    65     0
# 16430   3147    440  211085207     4    24    43    37  4428   316     0
# 16431    111     21  211686294    24   261    43    38   200    95    11
#
#        iid8 color_1 color_2 color_3 color_4
# 0       106   white   black    none    none
# 1         0   white   black    blue    none
# 2        76   black     red  yellow    none
# 3       200   black     red    blue  yellow
# 4         0   white   black    blue    none
# ...     ...     ...     ...     ...     ...
# 16427     0   black    gray    none    none
# 16428     0   black     red    none    none
# 16429     0   white    none    none    none
# 16430     0   black    gray  yellow    none
# 16431     0   white   black     red    none
#
# [16432 rows x 15 columns]

# %%
df3.to_csv('tidy_data.csv', index=False)
